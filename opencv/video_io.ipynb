# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
cap = cv2.VideoCapture('people.mp4')

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        print("No frames found")
        break

    cv2.imshow('video', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# No frames found

# %%
def filter(image):
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    img_blur = cv2.GaussianBlur(img_gray, (5,5), 0)

    c_edges = cv2.Canny(img_blur, 10, 70)

    ret, mask = cv2.threshold(c_edges, 70, 255, cv2.THRESH_BINARY_INV)

    return mask

cap = cv2.VideoCapture('people.mp4')

while cap.isOpened():
    ret, frame = cap.read()
    cv2.imshow('Filter', filter(frame))
    if cv2.waitKey(1) == 13:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 15
#      13 while cap.isOpened():
#      14     ret, frame = cap.read()
# ---> 15     cv2.imshow('Filter', filter(frame))
#      16     if cv2.waitKey(1) == 13:
#      17         break
#
# Cell In[8], line 2, in filter(image)
#       1 def filter(image):
# ----> 2     img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       3     img_blur = cv2.GaussianBlur(img_gray, (5,5), 0)
#       5     c_edges = cv2.Canny(img_blur, 10, 70)
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
